# %%
from edc import print_info
print_info("geodb-explore")
# Out:
# ***Notebook Title***
# GeoDB: Explore Datasets
#
# ***Notebook Description***
# Euro Data Cube GeoDB: Explore Datasets
#
#
# ***Notebook Dependencies***
# This notebook requires an active subscription to:
# * EDC GeoDB
# * EDC EOxHub Workspace

# %%
from edc import check_compatibility
check_compatibility("user-0.24.5", dependencies=["GEODB"])
# Out:
# <script type="text/javascript">
#         function toggle(id) {
#             el = document.getElementById(id);
#             el.style.display = el.style.display === "none" ? "block" : "none";
#         }
#     </script>
# This notebook is compatible with this base image version (user-0.24.5).
# ---------
#
# The following environment variables are available:
#
# * `GEODB_AUTH_DOMAIN`, `GEODB_API_SERVER_URL`, `GEODB_AUTH_CLIENT_ID`, `GEODB_AUTH_CLIENT_SECRET`, `GEODB_AUTH_AUD`, `GEODB_API_SERVER_PORT`

# %% [markdown]
# ## Exploring Data

# %%
from xcube_geodb.core.geodb import GeoDBClient

# %%
# utility needed for plotting
import matplotlib.pyplot as plt

# %%
geodb = GeoDBClient()

# %% [markdown]
# ### Get your user name

# %%
geodb.whoami
# Out:
# 'geodb_139b9f28-6757-4ffa-8345-3f658eb33850'

# %%
ds = geodb.get_my_collections()

if ds[(ds.database == geodb.whoami) & (ds.collection == 'land_use')].collection.count() == 0:
    # Have a look at fiona feature schema
    collections = {
            "land_use": 
            {
                "crs": 3794,
                "properties": 
                {
                    "RABA_PID": "float", 
                    "RABA_ID": "float", 
                    "D_OD": "date"
                }
            }
        }


    geodb.create_collections(collections)
    import geopandas
    import os
    gdf = geopandas.read_file(os.path.expanduser("~/.shared/notebooks/eurodatacube/notebooks/getting-started/data/sample/land_use.shp"))
    geodb.insert_into_collection('land_use', gdf)
# Out:
# Processing rows from 0 to 999
# Processing rows from 1000 to 1999
# Processing rows from 2000 to 2999
# Processing rows from 3000 to 3999
# Processing rows from 4000 to 4999
# Processing rows from 5000 to 5999
# Processing rows from 6000 to 6999
# Processing rows from 7000 to 7999
# Processing rows from 8000 to 8999
# Processing rows from 9000 to 9827

# %% [markdown]
# ### List Datasets
#
# __Step 1__: List all datasets a user has access to.

# %%
geodb.get_my_collections()
# Out:
#                                           owner  \
# 0    geodb_0b01bfcd-2d09-46f8-84e8-cb5720fba14c
# 1    geodb_0b01bfcd-2d09-46f8-84e8-cb5720fba14c
# 2    geodb_0d6df427-8c09-41b9-abc9-64ce13a68125
# 3    geodb_0d6df427-8c09-41b9-abc9-64ce13a68125
# 4    geodb_0e5d743f-2134-4561-8946-a073b039176f
# ..                                          ...
# 876                              geodb_geodb_ci
# 877                       geodb_lpis_iacs_admin
# 878                       geodb_lpis_iacs_admin
# 879                       geodb_lpis_iacs_admin
# 880                       geodb_lpis_iacs_admin
#
#                                        database            collection  \
# 0    geodb_0b01bfcd-2d09-46f8-84e8-cb5720fba14c  delineated_parcels_s
# 1    geodb_0b01bfcd-2d09-46f8-84e8-cb5720fba14c            test_batic
# 2    geodb_0d6df427-8c09-41b9-abc9-64ce13a68125              land_use
# 3    geodb_0d6df427-8c09-41b9-abc9-64ce13a68125              lpis_aut
# 4    geodb_0e5d743f-2134-4561-8946-a073b039176f          ai4eo_bboxes
# ..                                          ...                   ...
# 876                              geodb_geodb_ci              land_use
# 877                                   lpis_iacs          land_use_slo
# 878                                   lpis_iacs              lpis_aut
# 879                                   lpis_iacs              lpis_slo
# 880                                   lpis_iacs              metadata
#
#                table_name
# 0    delineated_parcels_s
# 1              test_batic
# 2                land_use
# 3                lpis_aut
# 4            ai4eo_bboxes
# ..                    ...
# 876              land_use
# 877          land_use_slo
# 878              lpis_aut
# 879              lpis_slo
# 880              metadata
#
# [881 rows x 4 columns]

# %% [markdown]
# __Step 2__: Let's get the whole content of a particular data set.

# %%
gdf = geodb.get_collection('land_use')
gdf
# Out:
#         id                        created_at modified_at  \
# 0        1  2021-09-29T14:43:11.765264+00:00        None
# 1        2  2021-09-29T14:43:11.765264+00:00        None
# 2        3  2021-09-29T14:43:11.765264+00:00        None
# 3        4  2021-09-29T14:43:11.765264+00:00        None
# 4        5  2021-09-29T14:43:11.765264+00:00        None
# ...    ...                               ...         ...
# 9822  9823  2021-09-29T14:43:19.821467+00:00        None
# 9823  9824  2021-09-29T14:43:19.821467+00:00        None
# 9824  9825  2021-09-29T14:43:19.821467+00:00        None
# 9825  9826  2021-09-29T14:43:19.821467+00:00        None
# 9826  9827  2021-09-29T14:43:19.821467+00:00        None
#
#                                                geometry  raba_pid  raba_id  \
# 0     POLYGON ((453952.629 91124.177, 453952.696 911...   4770326     1410
# 1     POLYGON ((453810.376 91150.199, 453812.552 911...   4770325     1300
# 2     POLYGON ((456099.635 97696.070, 456112.810 976...   2305689     7000
# 3     POLYGON ((455929.405 97963.785, 455933.284 979...   2305596     1100
# 4     POLYGON ((461561.512 96119.256, 461632.114 960...   2310160     1100
# ...                                                 ...       ...      ...
# 9822  POLYGON ((460637.334 96865.891, 460647.927 969...   6253989     1600
# 9823  POLYGON ((459467.868 96839.686, 459467.770 968...   6252044     1600
# 9824  POLYGON ((459488.998 94066.248, 459498.145 940...   6245985     2000
# 9825  POLYGON ((459676.680 94000.000, 459672.469 939...   6245986     2000
# 9826  POLYGON ((459690.580 94042.607, 459686.872 940...   6245987     2000
#
#             d_od
# 0     2019-03-26
# 1     2019-03-26
# 2     2019-02-25
# 3     2019-02-25
# 4     2019-03-11
# ...          ...
# 9822  2019-03-08
# 9823  2019-03-26
# 9824  2019-04-08
# 9825  2019-02-20
# 9826  2019-03-11
#
# [9827 rows x 7 columns]

# %% [markdown]
# __Step 3__: Plot the GeoDataframe, select a reasonable column to diplay

# %%
gdf.plot(column="raba_id", figsize=(15,15), cmap = 'jet')
plt.show()

# %% [markdown]
# __Step 5__: Subselect the data. Here: Select a specific use by defining an ID value to choose

# %%
gdfsub = geodb.get_collection('land_use', query='raba_id=eq.1410')
gdfsub.head()
# Out:
#    id                        created_at modified_at  \
# 0   1  2021-09-29T14:43:11.765264+00:00        None
# 1  62  2021-09-29T14:43:11.765264+00:00        None
# 2  22  2021-09-29T14:43:11.765264+00:00        None
# 3  28  2021-09-29T14:43:11.765264+00:00        None
# 4  32  2021-09-29T14:43:11.765264+00:00        None
#
#                                             geometry  raba_pid  raba_id  \
# 0  POLYGON ((453952.629 91124.177, 453952.696 911...   4770326     1410
# 1  POLYGON ((457261.001 96349.254, 457256.831 963...   3596498     1410
# 2  POLYGON ((455384.809 97907.054, 455380.659 979...   3616776     1410
# 3  POLYGON ((462585.734 93088.987, 462567.020 930...   3826126     1410
# 4  POLYGON ((457748.827 96167.354, 457748.394 961...   2309744     1410
#
#          d_od
# 0  2019-03-26
# 1  2019-01-05
# 2  2019-02-25
# 3  2019-01-23
# 4  2019-01-05

# %%
gdfsub.plot(column="raba_id", figsize=(15,15), cmap = 'jet')
plt.show()

# %% [markdown]
# __Step 6__: Filter by bbox, limit it to 200 entries

# %%
gdf = geodb.get_collection_by_bbox(collection="land_use", bbox = (452750.0, 88909.549, 464000.0, 102486.299), comparison_mode="contains", bbox_crs=3794, limit=200, offset=10)
gdf
# Out:
#       id                        created_at modified_at  \
# 0     11  2021-09-29T14:43:11.765264+00:00        None
# 1     12  2021-09-29T14:43:11.765264+00:00        None
# 2     13  2021-09-29T14:43:11.765264+00:00        None
# 3     14  2021-09-29T14:43:11.765264+00:00        None
# 4     15  2021-09-29T14:43:11.765264+00:00        None
# ..   ...                               ...         ...
# 195  206  2021-09-29T14:43:11.765264+00:00        None
# 196  207  2021-09-29T14:43:11.765264+00:00        None
# 197  208  2021-09-29T14:43:11.765264+00:00        None
# 198  209  2021-09-29T14:43:11.765264+00:00        None
# 199  210  2021-09-29T14:43:11.765264+00:00        None
#
#                                               geometry  raba_pid  raba_id  \
# 0    POLYGON ((460137.998 95628.898, 460111.001 956...   5983161     1100
# 1    POLYGON ((453673.609 91328.224, 453678.929 913...   5983074     1600
# 2    POLYGON ((460312.295 96127.114, 460300.319 961...   5983199     1600
# 3    POLYGON ((460459.445 96117.356, 460470.516 961...   5983217     1100
# 4    POLYGON ((457798.753 99628.982, 457783.076 996...   6299143     1600
# ..                                                 ...       ...      ...
# 195  POLYGON ((458460.702 94486.435, 458450.740 944...   5966292     1321
# 196  POLYGON ((458469.826 94472.438, 458463.978 944...   5966293     1500
# 197  POLYGON ((455171.131 90548.851, 455158.322 905...   3590222     1500
# 198  POLYGON ((456420.815 92626.252, 456428.630 926...   6305200     1500
# 199  POLYGON ((456437.664 92667.683, 456433.667 926...   6305202     1100
#
#            d_od
# 0    2019-03-11
# 1    2019-03-26
# 2    2019-03-11
# 3    2019-03-11
# 4    2019-03-04
# ..          ...
# 195  2019-01-05
# 196  2019-03-26
# 197  2019-01-18
# 198  2019-03-14
# 199  2019-03-14
#
# [200 rows x 7 columns]

# %%
gdf.plot(column="raba_pid", figsize=(15,15), cmap = 'jet')
plt.show()

# %% [markdown]
# __Step 6__: Fltering using PostGres Syntax; see https://www.postgresql.org/docs/9.1/index.html for details

# %%
gdf = geodb.get_collection_pg(collection='land_use', where='raba_id=1410')
gdf.head()
# Out:
#    id                        created_at modified_at  \
# 0   1  2021-09-29T14:43:11.765264+00:00        None
# 1  62  2021-09-29T14:43:11.765264+00:00        None
# 2  22  2021-09-29T14:43:11.765264+00:00        None
# 3  28  2021-09-29T14:43:11.765264+00:00        None
# 4  32  2021-09-29T14:43:11.765264+00:00        None
#
#                                             geometry  raba_pid  raba_id  \
# 0  POLYGON ((453952.629 91124.177, 453952.696 911...   4770326     1410
# 1  POLYGON ((457261.001 96349.254, 457256.831 963...   3596498     1410
# 2  POLYGON ((455384.809 97907.054, 455380.659 979...   3616776     1410
# 3  POLYGON ((462585.734 93088.987, 462567.020 930...   3826126     1410
# 4  POLYGON ((457748.827 96167.354, 457748.394 961...   2309744     1410
#
#          d_od
# 0  2019-03-26
# 1  2019-01-05
# 2  2019-02-25
# 3  2019-01-23
# 4  2019-01-05

# %%
gdf.plot(column="raba_pid", figsize=(15,15), cmap = 'jet')
plt.show()

# %% [markdown]
# __Step 7__: Fltering using PostGres Syntax Allowing Aggregation
# Here according to data, note that the data set has been reduced to 200 entries above

# %%
df = geodb.get_collection_pg('land_use', where='raba_id=1410', group='d_od', select='COUNT(d_od) as ct, d_od')
df.head()
# Out:
#    ct        d_od
# 0  12  2019-03-21
# 1  47  2019-02-25
# 2  17  2019-03-13
# 3  26  2019-02-20
# 4   2  2019-04-29
